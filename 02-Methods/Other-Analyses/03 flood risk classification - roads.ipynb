# %%
import pandas as pd
from os import listdir
from os.path import isfile, join
import pathlib

# file paths and names
path_input = '/Users/srilakshmi/Desktop/Thesis/04-Data-Analysis-Results/00-Data-Sources/00-Cloud-to-Street/01-District-level/Roads/Output/'
name_input_file = 'District-level_Roads_Recurrence.csv'

path_output = '/Users/srilakshmi/Desktop/Thesis/04-Data-Analysis-Results/00-Data-Sources/00-Cloud-to-Street/01-District-level/Roads/Output/'
name_output_file = 'District_Flood_Risk_Classification_Roads.csv'

# add in zeroes column
df = pd.read_csv(path_input+name_input_file, header=0)
zeroes = [0] * len(df)
df.insert(1, "Zeroes", zeroes, True)
df

# calculate average impact per year for population
return_periods = [2, 5, 10, 15, 20]
avg_impact_per_year = []

for i in range(0, len(df)):
    marg_impact_per_year = [] # collect marginal impact per year to then sum up

    for j in range(1, 6):
        x = ( df.iloc[i, j+1] - df.iloc[i, j] ) / return_periods[j-1]
        marg_impact_per_year.append(x)
        
    avg_impact_per_year.append(sum(marg_impact_per_year))

# add output to df
flood_risk_classification = df[['Region']]
colname = 'Avg Impact Per Year - Roads'

flood_risk_classification.insert(1,colname, avg_impact_per_year, True)
flood_risk_classification = flood_risk_classification.sort_values(colname) # sort from low to high avg impact per year
flood_risk_classification
# Out:
#                          Region  Avg Impact Per Year - Roads
# 0    Abura / Asebu / Kwamankese                     0.000000
# 100                     Juabeso                     0.000000
# 181                      Suaman                     0.000000
# 182             Suhum Municipal                     0.000000
# 97                      Jasikan                     0.000000
# ..                          ...                          ...
# 85                     Ga South                  2035.066667
# 107                  Ketu South                  2391.500000
# 112                     Kpandai                  2980.866667
# 105              Keta Municipal                  4728.666667
# 116             Krachi Nchumuru                  8620.800000
#
# [216 rows x 2 columns]

# %%
# save file to disk

flood_risk_classification.to_csv(path_output+name_output_file, index = False, header=True)
