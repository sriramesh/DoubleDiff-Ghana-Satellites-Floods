# %% [markdown]
# ## Measuring Impact
#
# Impact would be measured by double difference between the last observation before the introduction of the scheme (2018 - 2020) and the last observation under the scheme. So this would be:
#
# * Before: Last obs of 2017
# * After: Last obs of 2020
#
# ATE = (Avg_T_2020 - Avg_T_2017) - (Avg_C_2020 - Avg_C_2017)

# %%
var = 'pop_sum'

import pandas as pd

## output files
path_input = '/Users/srilakshmi/Desktop/Thesis/04-Data-Analysis-Results/02-Parallel-Trends-Analysis/'
name_input_file = 'Before_After_Outcome_Variable_Of_Interest.csv'

x = pd.read_csv(path_input+name_input_file)
x = x[x['year'] == 2017].append(x[x['year'] == 2019]) # only keep before and after data
x.columns = ['region', 'treatment', 'post', var]
x['post'] = x['post'].map({2017:0, 2019:1})
x
# Out:
#                         region  treatment  post  pop_sum
# 2     Kwahu Afram Plains North          1     0      0.0
# 8                   East Gonja          1     0      0.0
# 14               Gonja Central          1     0      0.0
# 20                   Sene East          1     0      0.0
# 26                 Krachi East          1     0      0.0
# ...                        ...        ...   ...      ...
# 1270               Jaman South          0     1      0.0
# 1276                   Jasikan          0     1      0.0
# 1282                Tano North          0     1      0.0
# 1288                   Kadjebi          0     1      0.0
# 1294              Sunyani West          0     1      0.0
#
# [432 rows x 4 columns]

# %%
import statsmodels.formula.api as smf

modelX = smf.ols(formula='pop_sum ~ treatment + post + (treatment * post)', data = x).fit()
print(modelX.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                pop_sum   R-squared:                       0.062
# Model:                            OLS   Adj. R-squared:                  0.056
# Method:                 Least Squares   F-statistic:                     9.449
# Date:                Thu, 08 Apr 2021   Prob (F-statistic):           4.67e-06
# Time:                        18:21:52   Log-Likelihood:                 2422.5
# No. Observations:                 432   AIC:                            -4837.
# Df Residuals:                     428   BIC:                            -4821.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept       5.706e-06   8.18e-05      0.070      0.944      -0.000       0.000
# treatment          0.0003      0.000      2.096      0.037    1.59e-05       0.000
# post            7.144e-07      0.000      0.006      0.995      -0.000       0.000
# treatment:post     0.0003      0.000      1.784      0.075   -3.13e-05       0.001
# ==============================================================================
# Omnibus:                      728.051   Durbin-Watson:                   1.345
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           250627.669
# Skew:                           9.922   Prob(JB):                         0.00
# Kurtosis:                     119.318   Cond. No.                         6.59
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# before = x[x['year'] == 2018].groupby('treatment').mean()['perc_pop']
# after = x[x['year'] == 2020].groupby('treatment').mean()['perc_pop']
# df = pd.DataFrame({'2018': before, '2020': after})
# df

# %%
# # IMPACT:
# treatment = df[df['Treatment'] == 1]['perc_pop'].iloc[1] - df[df['Treatment'] == 1]['perc_pop'].iloc[0]
# control = df[df['Treatment'] == 0]['perc_pop'].iloc[1] - df[df['Treatment'] == 0]['perc_pop'].iloc[0]

# print('On average, the treatment reduces the flood-affected population percentage by ' +
#       str(round(treatment - control,4)))
