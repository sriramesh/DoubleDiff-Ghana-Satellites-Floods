# %%
import pandas as pd

# %%
df = pd.read_stata('GHFW81DT/GHFW81FL.DTA')

df
# Out:
#     fw101 fw000          fw102  fw103  fw104   fw105  \
# 0     100   GH7        western   city     49    male
# 1     101   GH7  greater accra   city     26  female
# 2     102   GH7        western   city     25  female
# 3     103   GH7  greater accra   city     27    male
# 4     105   GH7  greater accra   city     32  female
# 5     200   GH7        central   city     43  female
# 6     201   GH7  greater accra   city     34  female
# 7     202   GH7        central   city     31  female
# 8     203   GH7  greater accra   city     24    male
# 9     205   GH7  greater accra   city     29    male
# 10    300   GH7  greater accra   city     45    male
# 11    301   GH7  greater accra   city     25  female
# 12    302   GH7  greater accra   city     25  female
# 13    303   GH7  greater accra   city     22    male
# 14    305   GH7  greater accra   city     41  female
# 15    400   GH7  greater accra   city     46  female
# 16    401   GH7  greater accra   city     30  female
# ...

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

shp = gpd.read_file('GHGE81FL/GHGE81FL.shp')

shp
# Out:
#               DHSID DHSCC  DHSYEAR  DHSCLUST CCFIPS ADM1FIPS ADM1FIPSNA  \
# 0    GH201900000001    GH   2019.0       1.0     GH     NULL       NULL
# 1    GH201900000002    GH   2019.0       2.0     GH     NULL       NULL
# 2    GH201900000003    GH   2019.0       3.0     GH     NULL       NULL
# 3    GH201900000004    GH   2019.0       4.0     GH     NULL       NULL
# 4    GH201900000005    GH   2019.0       5.0     GH     NULL       NULL
# ..              ...   ...      ...       ...    ...      ...        ...
# 195  GH201900000196    GH   2019.0     196.0     GH     NULL       NULL
# 196  GH201900000197    GH   2019.0     197.0     GH     NULL       NULL
# 197  GH201900000198    GH   2019.0     198.0     GH     NULL       NULL
# 198  GH201900000199    GH   2019.0     199.0     GH     NULL       NULL
# 199  GH201900000200    GH   2019.0     200.0     GH     NULL       NULL
#
#     ADM1SALBNA ADM1SALBCO  ADM1DHS  ... DHSREGCO    DHSREGNA SOURCE  \
# ...
