# %%
import pandas as pd
from os import listdir
from os.path import isfile, join
import pathlib
import sys

# insert at 1, 0 is the script path (or '' in REPL)
path_mod = '/Users/srilakshmi/Desktop/Thesis/Data/District-level/'
sys.path.insert(1, path_mod)

import clean

# %%
# file paths and file names
path_input = '/Users/srilakshmi/Desktop/Thesis/Data/District-level/Roads/Data-Recurrence/'
path_output = '/Users/srilakshmi/Desktop/Thesis/Data/District-level/Roads/Output/'
name_output_file = 'District-level_Roads_Recurrence.csv'

col_name_old = 'Roads Impacted'

recur_left = 41
recur_right = 47

# %%
# get list of file names
files = [f for f in listdir(path_input) if isfile(join(path_input, f))]
files.sort(reverse = False)
files
# Out:
# ['Roads Impacted in Ghana Ghana_Recurrence_02Year.csv',
#  'Roads Impacted in Ghana Ghana_Recurrence_05Year.csv',
#  'Roads Impacted in Ghana Ghana_Recurrence_10Year.csv',
#  'Roads Impacted in Ghana Ghana_Recurrence_15Year.csv',
#  'Roads Impacted in Ghana Ghana_Recurrence_20Year.csv']

# %%
# merge files
for i in range(0, 1):
    x = clean.clean_csv_recurrence(path_input, files[i], col_name_old, recur_left, recur_right)
    y = clean.clean_csv_recurrence(path_input, files[i+1], col_name_old, recur_left, recur_right)
    merged = clean.special_merge(left = x, right = y)
    
for i in range(2, 5):
    z = clean.clean_csv_recurrence(path_input, files[i], col_name_old, recur_left, recur_right)
    merged = clean.special_merge(left = merged, right = z)
    i += 1

merged
# Out:
#                          Region  02Year  05Year  10Year  15Year  20Year
# 0    Abura / Asebu / Kwamankese       0       0       0       0       0
# 1              Accra Metropolis       0      90     170     174     386
# 2                      Ada East     350     790    1870    2020    2330
# 3                      Ada West     620    1530    2570    3030    3410
# 4                        Adaklu       0       0       0       0       0
# ..                          ...     ...     ...     ...     ...     ...
# 211                  West Gonja       0       0     180     270     546
# 212               West Mamprusi      40     139    1019    3739   13660
# 213             Yendi Municipal       9     241     541     631     930
# 214                  Yilo Krobo       0       0       0       0       0
# 215                     Zabzugu      11      99     129     169     249
#
# [216 rows x 6 columns]

# %%
# save file to disk

merged.to_csv(path_output+name_output_file, index = False, header=True)
