# %% [markdown]
# ## Measuring Impact
#
# Impact would be measured by double difference between the last observation before the introduction of the scheme (2018 - 2020) and the last observation under the scheme. So this would be:
#
# * Before: Last obs of 2017
# * After: Last obs of 2020
#
# ATE = (Avg_T_2020 - Avg_T_2017) - (Avg_C_2020 - Avg_C_2017)

# %%
var = 'pop_sum'

import pandas as pd

## output files
path_input = '/Users/srilakshmi/Desktop/Thesis/04-Data-Analysis-Results/02-Parallel-Trends-Analysis/'
name_input_file = 'Before_After_Outcome_Variable_Of_Interest.csv'

x = pd.read_csv(path_input+name_input_file)
x = x[x['year'] == 2017].append(x[x['year'] == 2019]) # only keep before and after data
x.columns = ['region', 'treatment', 'post', var]
x['post'] = x['post'].map({2017:0, 2019:1})
x
# Out:
#                 region  treatment  post  pop_sum
# 2              Jasikan          0     0      0.0
# 8              Kadjebi          0     0      0.0
# 14       Nkwanta South          1     0      0.0
# 20     Krachi Nchumuru          1     0      0.0
# 26       Nkwanta North          1     0      0.0
# ...                ...        ...   ...      ...
# 1270  Sefwi Akontombra          0     1      0.0
# 1276           Juabeso          0     1      0.0
# 1282            Suaman          0     1      0.0
# 1288      Sefwi-Wiawso          0     1      0.0
# 1294          Bia East          0     1      0.0
#
# [432 rows x 4 columns]

# %%
import statsmodels.formula.api as smf

modelX = smf.ols(formula='pop_sum ~ treatment + post + (treatment * post)', data = x).fit()
print(modelX.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                pop_sum   R-squared:                       0.060
# Model:                            OLS   Adj. R-squared:                  0.054
# Method:                 Least Squares   F-statistic:                     9.166
# Date:                Sat, 10 Apr 2021   Prob (F-statistic):           6.87e-06
# Time:                        11:10:38   Log-Likelihood:                -2630.2
# No. Observations:                 432   AIC:                             5268.
# Df Residuals:                     428   BIC:                             5285.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept          0.7899      9.823      0.080      0.936     -18.517      20.097
# treatment         29.2803     14.658      1.998      0.046       0.470      58.091
# post               0.7140     13.891      0.051      0.959     -26.590      28.018
# treatment:post    37.3064     20.729      1.800      0.073      -3.437      78.050
# ==============================================================================
# Omnibus:                      664.709   Durbin-Watson:                   1.538
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           126531.942
# Skew:                           8.517   Prob(JB):                         0.00
# Kurtosis:                      85.094   Cond. No.                         6.59
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
