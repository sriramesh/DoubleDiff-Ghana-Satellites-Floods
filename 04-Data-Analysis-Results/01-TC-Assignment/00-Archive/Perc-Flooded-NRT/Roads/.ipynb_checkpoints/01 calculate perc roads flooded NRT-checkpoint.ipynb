# %%
import pandas as pd
import matplotlib.pyplot as plt

# file paths and names
path_input = '/Users/srilakshmi/Desktop/Thesis/04-Data-Analysis-Results/00-Data-Sources/00-Cloud-to-Street/01-District-level/Totals/'
name_input_file = 'Impacts-Ghana_MaxFlood_20200715_20201014.csv'

path_output = '/Users/srilakshmi/Desktop/Thesis/04-Data-Analysis-Results/01-TC-Assignment/Perc-Flooded-NRT/Roads/'

name_output_file = 'Perc_Roads_Flooded.csv'

tot_pop = pd.read_csv(path_input+name_input_file, header=0)
tot_pop

colnames = []
for col in tot_pop.columns:
    colnames.append(col)

tot_pop = tot_pop.dropna(subset=[colnames[2]])
# tot_pop = tot_pop[[colnames[1], colnames[2], colnames[6]]]
# tot_pop = tot_pop.rename(columns={colnames[1]: "Region", colnames[2]: "Total Pop", colnames[6]: "Flooded Pop"})
# tot_pop['Perc Population Flooded'] = list(tot_pop['Flooded Pop']/tot_pop['Total Pop'])

# tot_pop = tot_pop.drop(columns=['Total Pop', 'Flooded Pop'])
# tot_pop = tot_pop.sort_values(by=['Region'])

# tot_pop
# Out:
#                        |                   |__District  |__Total_Population  \
# 0     Population_Impacts               La Dade Kotopon             394390.0
# 1                    NaN              Sekondi Takoradi             651924.0
# 2                    NaN                    Agona West             124270.0
# 3                    NaN  Komenda Edna Eguafo / Abirem             162663.0
# 4                    NaN              Accra Metropolis            1836282.0
# ...                  ...                           ...                  ...
# 1508                 NaN              Sefwi Akontombra                  NaN
# 1509                 NaN                       Juabeso                  NaN
# 1510                 NaN                        Suaman                  NaN
# 1511                 NaN                  Sefwi-Wiawso                  NaN
# 1512                 NaN                      Bia East                  NaN
#
#                  |__Data__deployment_id |__Data__dtime_start  \
# 0     Ghana_MaxFlood__20200715_20201014           2020-07-15
# 1     Ghana_MaxFlood__20200715_20201014           2020-07-15
# 2     Ghana_MaxFlood__20200715_20201014           2020-07-15
# 3     Ghana_MaxFlood__20200715_20201014           2020-07-15
# 4     Ghana_MaxFlood__20200715_20201014           2020-07-15
# ...                                 ...                  ...
# 1508  Ghana_MaxFlood__20200715_20201014           2020-07-15
# 1509  Ghana_MaxFlood__20200715_20201014           2020-07-15
# 1510  Ghana_MaxFlood__20200715_20201014           2020-07-15
# 1511  Ghana_MaxFlood__20200715_20201014           2020-07-15
# 1512  Ghana_MaxFlood__20200715_20201014           2020-07-15
#
#      |__Data__dtime_end  |__Data__value  |__Total_Cropland_km2  \
# 0            2020-10-14          7906.0                    NaN
# 1            2020-10-14          6679.0                    NaN
# 2            2020-10-14          6526.0                    NaN
# 3            2020-10-14          5698.0                    NaN
# 4            2020-10-14          3724.0                    NaN
# ...                 ...             ...                    ...
# 1508         2020-10-14             0.0                    NaN
# 1509         2020-10-14             0.0                    NaN
# 1510         2020-10-14             0.0                    NaN
# 1511         2020-10-14             0.0                    NaN
# 1512         2020-10-14             0.0                    NaN
#
#       |__Total_RoadLength_m  |__Total_Area_km2  |__Total_Hospitals  \
# 0                       NaN                NaN                 NaN
# 1                       NaN                NaN                 NaN
# 2                       NaN                NaN                 NaN
# 3                       NaN                NaN                 NaN
# 4                       NaN                NaN                 NaN
# ...                     ...                ...                 ...
# 1508                    NaN                NaN                 NaN
# 1509                    NaN                NaN                 NaN
# 1510                    NaN                NaN                 NaN
# 1511                    NaN                NaN                 NaN
# 1512                    NaN                NaN                 NaN
#
#       |__Total_Markets  |__Total_Schools
# 0                  NaN               NaN
# 1                  NaN               NaN
# 2                  NaN               NaN
# 3                  NaN               NaN
# 4                  NaN               NaN
# ...                ...               ...
# 1508               NaN               0.0
# 1509               NaN               0.0
# 1510               NaN               0.0
# 1511               NaN               1.0
# 1512               NaN               0.0
#
# [1513 rows x 13 columns]
