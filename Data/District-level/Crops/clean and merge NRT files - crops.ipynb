# %%
import pandas as pd
from os import listdir
from os.path import isfile, join
import pathlib

# %%
# file and column names used
col_name_old = "Crops Impacted"
monitor_name_pos_left = 38
monitor_name_pos_right = 55
historic_name_pos_left = 39
historic_name_pos_right = 56

# file paths and file names
path_main = '/Users/srilakshmi/Desktop/Thesis/Data/District-level/Crops/'
name_folder_data = 'Data-NRT/'
path_data = path_main+name_folder_data
name_output_file = 'District-level_Crops_NRT.csv'

# %%
# data cleaning functions

def clean_csv_monitor(string):
    
    df = pd.read_csv(name_folder_data+string, header=0)
    df = df.drop_duplicates()
    df = df.rename(columns={col_name_old: string[monitor_name_pos_left:monitor_name_pos_right]})
    df = df.sort_values(by=['Region'])
    
    return df

def clean_csv_historic(string):
    
    df = pd.read_csv(name_folder_data+string, header=0)
    df = df.drop_duplicates()
    df = df.rename(columns={col_name_old: string[historic_name_pos_left:historic_name_pos_right]})
    df = df.sort_values(by=['Region'])
    
    return df

def special_merge(left,right):
    merged = left.set_index('Region').join(right.set_index('Region')) # merged file 0 and file 1 together    
    merged.index.name = 'Region'
    merged.reset_index(inplace=True)
    
    return merged

# %%
# get list of file names
files = [f for f in listdir(path_data) if isfile(join(path_data, f))]
files
# Out:
# ['Crops Impacted in Ghana Ghana_Monitor_20200923_20200930.csv',
#  'Crops Impacted in Ghana Ghana_Monitor_20200722_20200729.csv',
#  'Crops Impacted in Ghana Ghana_Historic_20190901_20190920.csv',
#  'Crops Impacted in Ghana Ghana_Monitor_20200819_20200826.csv',
#  'Crops Impacted in Ghana Ghana_Monitor_20200826_20200902.csv',
#  'Crops Impacted in Ghana Ghana_Monitor_20200805_20200812.csv',
#  'Crops Impacted in Ghana Ghana_Monitor_20200909_20200916.csv',
#  'Crops Impacted in Ghana Ghana_Monitor_20201014_20201021.csv',
#  'Crops Impacted in Ghana Ghana_Monitor_20200812_20200819.csv',
#  'Crops Impacted in Ghana Ghana_Historic_20180815_20181015.csv',
#  'Crops Impacted in Ghana Ghana_Monitor_20201007_20201014.csv',
#  'Crops Impacted in Ghana Ghana_Monitor_20200902_20200909.csv',
#  'Crops Impacted in Ghana Ghana_Monitor_20200916_20200923.csv',
#  'Crops Impacted in Ghana Ghana_Monitor_20200715_20200722.csv',
#  'Crops Impacted in Ghana Ghana_Monitor_20200930_20201007.csv']

# %%
# merge csv files

for i in range(0, 1):
    x = clean_csv_monitor(files[i])
    y = clean_csv_monitor(files[i+1])
    merged = special_merge(left = x, right = y)

for i in range(2, 3):
    z = clean_csv_historic(files[i])
    merged = special_merge(left = merged, right = z)
    
for i in range(3, 9):
    z = clean_csv_monitor(files[i])
    merged = special_merge(left = merged, right = z)
    i += 1
    
for i in range(9,10):
    z = clean_csv_historic(files[i])
    merged = special_merge(left = merged, right = z)
    
for i in range(10,15):
    z = clean_csv_monitor(files[i])
    merged = special_merge(left = merged, right = z)
    
merged
# Out:
#                          Region  20200923_20200930  20200722_20200729  \
# 0    Abura / Asebu / Kwamankese               0.00               0.00
# 1              Accra Metropolis               0.00               0.00
# 2                      Ada East               0.00               0.00
# 3                      Ada West               0.00               0.00
# 4                        Adaklu               0.00               0.00
# ..                          ...                ...                ...
# 211                  West Gonja               7.27               0.00
# 212               West Mamprusi             113.22               0.13
# 213             Yendi Municipal               7.19               0.08
# 214                  Yilo Krobo               0.00               0.00
# 215                     Zabzugu               3.86               0.02
#
#      20190901_20190920  20200819_20200826  20200826_20200902  \
# 0                 0.00               0.00               0.00
# 1                 0.02               0.00               0.00
# 2                 0.97               0.00               0.00
# 3                 1.08               0.01               0.01
# 4                 0.10               0.01               0.00
# ..                 ...                ...                ...
# 211               1.12               0.04               0.18
# 212             136.41               6.37              18.90
# 213               4.30               0.11               0.00
# 214               0.03               0.00               0.00
# 215               1.04               0.01               0.00
#
#      20200805_20200812  20200909_20200916  20201014_20201021  \
# 0                 0.00               0.00               0.00
# 1                 0.00               0.00               0.00
# 2                 0.29               0.09               1.15
# 3                 0.32               0.00               1.55
# 4                 0.02               0.00               0.01
# ..                 ...                ...                ...
# 211               0.00               1.07               0.95
# 212               1.78             120.02              36.89
# 213               0.05               8.36               3.58
# 214               0.00               0.00               0.01
# 215               0.03               4.71               4.15
#
#      20200812_20200819  20180815_20181015  20201007_20201014  \
# 0                 0.00               0.00               0.00
# 1                 0.00               0.00               0.01
# 2                 0.21               0.00               0.00
# 3                 0.34               0.00               0.00
# 4                 0.01               0.00               0.00
# ..                 ...                ...                ...
# 211               0.01              10.17               0.96
# 212               0.35             131.29              77.98
# 213               0.20               3.70               5.44
# 214               0.01               0.00               0.00
# 215               0.04               5.13               2.63
#
#      20200902_20200909  20200916_20200923  20200715_20200722  \
# 0                 0.00               0.00               0.00
# 1                 0.00               0.00               0.00
# 2                 0.15               0.00               0.04
# 3                 0.28               0.00               0.05
# 4                 0.00               0.00               0.00
# ..                 ...                ...                ...
# 211               0.00               5.47               0.01
# 212             109.68             120.06               0.57
# 213               5.39               6.48               0.00
# 214               0.00               0.00               0.00
# 215               1.67               3.73               0.07
#
#      20200930_20201007
# 0                 0.00
# 1                 0.00
# 2                 0.00
# 3                 0.00
# 4                 0.00
# ..                 ...
# 211               1.32
# 212              94.30
# 213               4.61
# 214               0.00
# 215               2.14
#
# [216 rows x 16 columns]

# %%
# save file to disk

merged.to_csv(path_main+name_output_file, index = False, header=True)
