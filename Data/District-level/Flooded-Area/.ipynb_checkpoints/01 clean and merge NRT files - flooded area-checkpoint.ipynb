# %%
import pandas as pd
from os import listdir
from os.path import isfile, join
import pathlib
import sys

# insert at 1, 0 is the script path (or '' in REPL)
path_mod = '/Users/srilakshmi/Desktop/Thesis/Data/District-level/'
sys.path.insert(1, path_mod)

import clean

# %%
# file and column names used
col_name_old = "Flooded Area Impacted"
monitor_name_pos_left = 45
monitor_name_pos_right = 62
historic_name_pos_left = 46
historic_name_pos_right = 63

# file paths and file names
path_input = '/Users/srilakshmi/Desktop/Thesis/Data/District-level/Flooded-Area/Data-NRT/'
path_output = '/Users/srilakshmi/Desktop/Thesis/Data/District-level/Flooded-Area/Output/'
name_output_file = 'District-level_Flooded_Area_NRT.csv'

# %%
# # data cleaning functions

# def clean_csv_monitor(string):
    
#     df = pd.read_csv(name_folder_data+string, header=0)
#     df = df.drop_duplicates()
#     df = df.rename(columns={col_name_old: string[monitor_name_pos_left:monitor_name_pos_right]})
#     df = df.sort_values(by=['Region'])
    
#     return df

# def clean_csv_historic(string):
    
#     df = pd.read_csv(name_folder_data+string, header=0)
#     df = df.drop_duplicates()
#     df = df.rename(columns={col_name_old: string[historic_name_pos_left:historic_name_pos_right]})
#     df = df.sort_values(by=['Region'])
    
#     return df

# def special_merge(left,right):
#     merged = left.set_index('Region').join(right.set_index('Region')) # merged file 0 and file 1 together    
#     merged.index.name = 'Region'
#     merged.reset_index(inplace=True)
    
#     return merged

# %%
# get list of file names
files = [f for f in listdir(path_input) if isfile(join(path_input, f))]
files
# Out:
# ['Flooded Area Impacted in Ghana Ghana_Monitor_20200812_20200819.csv',
#  'Flooded Area Impacted in Ghana Ghana_Monitor_20200805_20200812.csv',
#  'Flooded Area Impacted in Ghana Ghana_Monitor_20200909_20200916.csv',
#  'Flooded Area Impacted in Ghana Ghana_Monitor_20201014_20201021.csv',
#  'Flooded Area Impacted in Ghana Ghana_Historic_20190901_20190920.csv',
#  'Flooded Area Impacted in Ghana Ghana_Monitor_20200819_20200826.csv',
#  'Flooded Area Impacted in Ghana Ghana_Monitor_20200826_20200902.csv',
#  'Flooded Area Impacted in Ghana Ghana_Monitor_20200923_20200930.csv',
#  'Flooded Area Impacted in Ghana Ghana_Monitor_20200722_20200729.csv',
#  'Flooded Area Impacted in Ghana Ghana_Monitor_20200715_20200722.csv',
#  'Flooded Area Impacted in Ghana Ghana_Monitor_20200916_20200923.csv',
#  'Flooded Area Impacted in Ghana Ghana_Monitor_20200930_20201007.csv',
#  'Flooded Area Impacted in Ghana Ghana_Monitor_20200902_20200909.csv',
#  'Flooded Area Impacted in Ghana Ghana_Monitor_20201007_20201014.csv',
#  'Flooded Area Impacted in Ghana Ghana_Historic_20180815_20181015.csv']

# %%
# merge csv files

for i in range(0, 1):
    x = clean.clean_csv_monitor(col_name_old, path_input, files[i], monitor_name_pos_left, monitor_name_pos_right)
    y = clean.clean_csv_monitor(col_name_old, path_input, files[i+1], monitor_name_pos_left, monitor_name_pos_right)
    merged = clean.special_merge(left = x, right = y)

for i in range(2, 4):
    z = clean.clean_csv_monitor(col_name_old, path_input, files[i], monitor_name_pos_left, monitor_name_pos_right)
    merged = clean.special_merge(left = merged, right = z)
    i += 1

for i in range(4, 5):
    z = clean.clean_csv_historic(col_name_old, path_input, files[i], historic_name_pos_left, historic_name_pos_right)
    merged = clean.special_merge(left = merged, right = z)
    
for i in range(5, 14):
    z = clean.clean_csv_monitor(col_name_old, path_input, files[i], monitor_name_pos_left, monitor_name_pos_right)
    merged = clean.special_merge(left = merged, right = z)
    i += 1
    
for i in range(14,15):
    z = clean.clean_csv_historic(col_name_old, path_input, files[i], historic_name_pos_left, historic_name_pos_right)
    merged = clean.special_merge(left = merged, right = z)
    
merged
# Out:
#                          Region  20200812_20200819  20200805_20200812  \
# 0    Abura / Asebu / Kwamankese               0.01               0.01
# 1              Accra Metropolis               0.03               0.07
# 2                      Ada East               3.71               4.16
# 3                      Ada West               1.87               1.96
# 4                        Adaklu               0.07               0.12
# ..                          ...                ...                ...
# 202                  West Gonja               0.28               0.02
# 203               West Mamprusi               0.46               2.85
# 204             Yendi Municipal               0.56               0.19
# 205                  Yilo Krobo               0.05               0.03
# 206                     Zabzugu               0.54               0.11
#
#      20200909_20200916  20201014_20201021  20190901_20190920  \
# 0                 0.00               0.01               0.16
# 1                 0.00               0.16               0.51
# 2                 3.11              14.90              15.27
# 3                 0.00              14.70               6.87
# 4                 0.00               0.11               0.32
# ..                 ...                ...                ...
# 202               6.13               4.83              10.68
# 203             174.90              59.47             203.95
# 204              12.46               5.98               8.52
# 205               0.00               0.40               0.38
# 206               9.35               9.14               3.67
#
#      20200819_20200826  20200826_20200902  20200923_20200930  \
# 0                 0.00               0.00               0.01
# 1                 0.00               0.00               0.00
# 2                 0.08               0.08               0.01
# 3                 0.02               0.01               0.00
# 4                 0.07               0.01               0.00
# ..                 ...                ...                ...
# 202               0.13               0.34              31.56
# 203              10.30              23.20             172.46
# 204               0.16               0.00              12.44
# 205               0.01               0.00               0.19
# 206               0.05               0.00              10.50
#
#      20200722_20200729  20200715_20200722  20200916_20200923  \
# 0                 0.04               0.01               0.00
# 1                 0.01               0.10               0.00
# 2                 0.06               0.95               0.00
# 3                 0.00               0.43               0.00
# 4                 0.00               0.00               0.00
# ..                 ...                ...                ...
# 202               0.18               0.69              27.01
# 203               0.25               0.98             178.26
# 204               0.11               0.01               9.66
# 205               0.00               0.00               0.18
# 206               0.04               0.14               7.64
#
#      20200930_20201007  20200902_20200909  20201007_20201014  \
# 0                 0.00               0.00               0.02
# 1                 0.03               0.04               0.13
# 2                 0.00               4.12               0.01
# 3                 0.00               2.12               0.00
# 4                 0.00               0.03               0.00
# ..                 ...                ...                ...
# 202               7.63               0.05               5.41
# 203             145.18             155.99             116.22
# 204               8.14               8.17               8.77
# 205               0.28               0.00               0.28
# 206               5.15               3.02               6.47
#
#      20180815_20181015
# 0                 0.00
# 1                 0.00
# 2                 0.00
# 3                 0.00
# 4                 0.00
# ..                 ...
# 202              48.80
# 203             194.66
# 204               8.50
# 205               0.00
# 206              12.94
#
# [207 rows x 16 columns]

# %%
# save file to disk

merged.to_csv(path_output+name_output_file, index = False, header=True)
