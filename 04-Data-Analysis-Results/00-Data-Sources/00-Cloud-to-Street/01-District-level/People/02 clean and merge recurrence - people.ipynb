# %%
import pandas as pd
from os import listdir
from os.path import isfile, join
import pathlib
import sys

# insert at 1, 0 is the script path (or '' in REPL)
path_mod = '/Users/srilakshmi/Desktop/Thesis/04-Data-Analysis-Results/00-Data-Sources/00-Cloud-to-Street/01-District-level/'
sys.path.insert(1, path_mod)

import clean

# %%
# file paths and file names
path_input = '/Users/srilakshmi/Desktop/Thesis/04-Data-Analysis-Results/00-Data-Sources/00-Cloud-to-Street/01-District-level/People/Data-Recurrence/'
path_output = '/Users/srilakshmi/Desktop/Thesis/04-Data-Analysis-Results/00-Data-Sources/00-Cloud-to-Street/01-District-level/People/Output/'
name_output_file = 'District-level_People_Recurrence.csv'

col_name_old = "People Impacted"

recur_left = 42
recur_right = 48

# %%
# get list of file names
files = [f for f in listdir(path_input) if isfile(join(path_input, f))]
files.sort(reverse = False)
files
# Out:
# ['People Impacted in Ghana Ghana_Recurrence_02Year.csv',
#  'People Impacted in Ghana Ghana_Recurrence_05Year.csv',
#  'People Impacted in Ghana Ghana_Recurrence_10Year.csv',
#  'People Impacted in Ghana Ghana_Recurrence_15Year.csv',
#  'People Impacted in Ghana Ghana_Recurrence_20Year.csv']

# %%
# merge files
for i in range(0, 1):
    x = clean.clean_csv_recurrence(path_input, files[i], col_name_old, recur_left, recur_right)
    y = clean.clean_csv_recurrence(path_input, files[i+1], col_name_old, recur_left, recur_right)
    merged = clean.special_merge(left = x, right = y)
    
for i in range(2, 5):
    z = clean.clean_csv_recurrence(path_input, files[i], col_name_old, recur_left, recur_right)
    merged = clean.special_merge(left = merged, right = z)
    i += 1

merged
# Out:
#                          Region  02Year  05Year  10Year  15Year  20Year
# 0    Abura / Asebu / Kwamankese       0       0       0       0       0
# 1              Accra Metropolis      41     356     807    1071    1276
# 2                      Ada East       0      80     230     328     410
# 3                      Ada West      18     384     658     801     989
# 4                        Adaklu       0       0       0       0       0
# ..                          ...     ...     ...     ...     ...     ...
# 211                  West Gonja       0       0       0       0       0
# 212               West Mamprusi      10      20      40      77      87
# 213             Yendi Municipal       0       0      26      26      26
# 214                  Yilo Krobo       0       0       0       0       0
# 215                     Zabzugu       0       0       0       0       0
#
# [216 rows x 6 columns]

# %%
# save file to disk

merged.to_csv(path_output+name_output_file, index = False, header=True)
