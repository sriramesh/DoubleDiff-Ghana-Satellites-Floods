# %%
import pandas as pd
from os import listdir
from os.path import isfile, join
import pathlib

# %%
# file and column names used
col_name_old = "People Impacted"
monitor_name_pos_left = 39
monitor_name_pos_right = 56
historic_name_pos_left = 40
historic_name_pos_right = 57

# file paths and file names
path_main = '/Users/srilakshmi/Desktop/Thesis/Data/District-level/People/'
name_folder_data = 'Data-NRT/'
path_data = path_main+name_folder_data
name_output_file = 'District-level_People_NRT.csv'

# %%
# data cleaning functions

def clean_csv_monitor(string):
    
    df = pd.read_csv(name_folder_data+string, header=0)
    df = df.drop_duplicates()
    df = df.rename(columns={col_name_old: string[monitor_name_pos_left:monitor_name_pos_right]})
    df = df.sort_values(by=['Region'])
    
    return df

def clean_csv_historic(string):
    
    df = pd.read_csv(name_folder_data+string, header=0)
    df = df.drop_duplicates()
    df = df.rename(columns={col_name_old: string[historic_name_pos_left:historic_name_pos_right]})
    df = df.sort_values(by=['Region'])
    
    return df

def special_merge(left,right):
    merged = left.set_index('Region').join(right.set_index('Region')) # merged file 0 and file 1 together    
    merged.index.name = 'Region'
    merged.reset_index(inplace=True)
    
    return merged

# %%
# get list of file names
files = [f for f in listdir(path_data) if isfile(join(path_data, f))]
files
# Out:
# ['People Impacted in Ghana Ghana_Monitor_20201007_20201014.csv',
#  'People Impacted in Ghana Ghana_Monitor_20200902_20200909.csv',
#  'People Impacted in Ghana Ghana_Historic_20190901_20190920.csv',
#  'People Impacted in Ghana Ghana_Monitor_20200930_20201007.csv',
#  'People Impacted in Ghana Ghana_Monitor_20200916_20200923.csv',
#  'People Impacted in Ghana Ghana_Monitor_20200715_20200722.csv',
#  'People Impacted in Ghana Ghana_Monitor_20200923_20200930.csv',
#  'People Impacted in Ghana Ghana_Monitor_20200722_20200729.csv',
#  'People Impacted in Ghana Ghana_Monitor_20200826_20200902.csv',
#  'People Impacted in Ghana Ghana_Monitor_20200819_20200826.csv',
#  'People Impacted in Ghana Ghana_Monitor_20200805_20200812.csv',
#  'People Impacted in Ghana Ghana_Monitor_20200909_20200916.csv',
#  'People Impacted in Ghana Ghana_Monitor_20201014_20201021.csv',
#  'People Impacted in Ghana Ghana_Historic_20180815_20181015.csv',
#  'People Impacted in Ghana Ghana_Monitor_20200812_20200819.csv']

# %%
# merge csv files

for i in range(0, 1):
    x = clean_csv_monitor(files[i])
    y = clean_csv_monitor(files[i+1])
    merged = special_merge(left = x, right = y)

for i in range(2, 3):
    z = clean_csv_historic(files[i])
    merged = special_merge(left = merged, right = z)
    
for i in range(3, 13):
    z = clean_csv_monitor(files[i])
    merged = special_merge(left = merged, right = z)
    i += 1
    
for i in range(13,14):
    z = clean_csv_historic(files[i])
    merged = special_merge(left = merged, right = z)
    
for i in range(14,15):
    z = clean_csv_monitor(files[i])
    merged = special_merge(left = merged, right = z)
    
merged
# Out:
#                          Region  20201007_20201014  20200902_20200909  \
# 0    Abura / Asebu / Kwamankese                  0                  0
# 1              Accra Metropolis                332                162
# 2                      Ada East                  0                550
# 3                      Ada West                  0                334
# 4                        Adaklu                  0                  0
# ..                          ...                ...                ...
# 211                  West Gonja                  0                  0
# 212               West Mamprusi                133                125
# 213             Yendi Municipal                104                 13
# 214                  Yilo Krobo                  0                  0
# 215                     Zabzugu                 16                  0
#
#      20190901_20190920  20200930_20201007  20200916_20200923  \
# 0                  540                  0                  0
# 1                 8143                205                  0
# 2                  802                  0                  0
# 3                 1338                  0                  0
# 4                  322                  0                  0
# ..                 ...                ...                ...
# 211                 22                 11                  0
# 212                243                165                155
# 213                 13                845                 14
# 214                 35                  0                  0
# 215                110                112                  0
#
#      20200715_20200722  20200923_20200930  20200722_20200729  \
# 0                    0                 80                  0
# 1                  496                  0                164
# 2                   40                  0                 50
# 3                   20                  0                  0
# 4                    0                  0                  0
# ..                 ...                ...                ...
# 211                 11                  0                  0
# 212                 50                142                 10
# 213                  0                 13                 39
# 214                  0                  0                  0
# 215                 32                 16                  0
#
#      20200826_20200902  20200819_20200826  20200805_20200812  \
# 0                    0                  0                 16
# 1                    0                  0                106
# 2                    0                  0                 62
# 3                    0                 30                216
# 4                    0                  0                  0
# ..                 ...                ...                ...
# 211                  0                  0                  0
# 212                 26                 16                  0
# 213                  0                  0                  0
# 214                  0                  0                  0
# 215                  0                  0                  0
#
#      20200909_20200916  20201014_20201021  20180815_20181015  \
# 0                    0                  0                  0
# 1                    0                283                  0
# 2                  100                840                  0
# 3                    0               2073                  0
# 4                    0                  0                  0
# ..                 ...                ...                ...
# 211                  0                  0                 22
# 212                206                 76               1215
# 213                 13                104                 52
# 214                  0                105                  0
# 215                  0                  0               1173
#
#      20200812_20200819
# 0                  0.0
# 1                 82.0
# 2                104.0
# 3                270.0
# 4                  0.0
# ..                 ...
# 211                0.0
# 212              140.0
# 213               26.0
# 214                0.0
# 215               16.0
#
# [216 rows x 16 columns]

# %%
# save file to disk

merged.to_csv(path_main+name_output_file, index = False, header=True)
