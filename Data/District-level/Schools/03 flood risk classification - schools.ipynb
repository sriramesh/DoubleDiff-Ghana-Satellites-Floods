# %%
import pandas as pd
from os import listdir
from os.path import isfile, join
import pathlib

# %%
# file paths and names
path_input = '/Users/srilakshmi/Desktop/Thesis/Data/District-level/Schools/'
name_input_file = 'District-level_Schools_Recurrence.csv'

path_output = '/Users/srilakshmi/Desktop/Thesis/Treatment-Control-Assignment/Flood-Risk-Classification/'
name_output_file = 'District_Flood_Risk_Classification_Schools.csv'

# %%
# add in zeroes column
df = pd.read_csv(path_input+name_input_file, header=0)
zeroes = [0] * len(df)
df.insert(1, "Zeroes", zeroes, True)
df
# Out:
#                          Region  Zeroes  02Year  05Year  10Year  15Year  \
# 0    Abura / Asebu / Kwamankese       0       0       0       0       0
# 1              Accra Metropolis       0       0       0       0       0
# 2                      Ada East       0       0       0       0       0
# 3                      Ada West       0       0       0       0       0
# 4                        Adaklu       0       0       0       0       0
# ..                          ...     ...     ...     ...     ...     ...
# 211                  West Gonja       0       0       0       0       0
# 212               West Mamprusi       0       0       0       0       0
# 213             Yendi Municipal       0       0       0       0       0
# 214                  Yilo Krobo       0       0       0       0       0
# 215                     Zabzugu       0       0       0       0       0
#
#      20Year
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
# ..      ...
# 211       0
# 212       0
# 213       0
# 214       0
# 215       0
#
# [216 rows x 7 columns]

# %%
# calculate average impact per year for population
return_periods = [2, 5, 10, 15, 20]
avg_impact_per_year = []

for i in range(0, len(df)):
    marg_impact_per_year = [] # collect marginal impact per year to then sum up

    for j in range(1, 6):
        x = ( df.iloc[i, j+1] - df.iloc[i, j] ) / return_periods[j-1]
        marg_impact_per_year.append(x)
        
    avg_impact_per_year.append(sum(marg_impact_per_year))

# %%
# add output to df
flood_risk_classification = df[['Region']]
colname = 'Avg Impact Per Year - Schools'

flood_risk_classification.insert(1,colname, avg_impact_per_year, True)
flood_risk_classification = flood_risk_classification.sort_values(colname) # sort from low to high avg impact per year
flood_risk_classification
# Out:
#                          Region  Avg Impact Per Year - Schools
# 0    Abura / Asebu / Kwamankese                            0.0
# 136                        Mion                            0.0
# 137                      Mpohor                            0.0
# 138                      Nabdam                            0.0
# 139             Nadowli / Kaleo                            0.0
# ..                          ...                            ...
# 3                      Ada West                            0.0
# 107                  Ketu South                            0.1
# 105              Keta Municipal                            0.2
# 64                 Builsa North                            0.5
# 187      Tamale North Sub Metro                            0.5
#
# [216 rows x 2 columns]

# %%
# save file to disk

flood_risk_classification.to_csv(path_output+name_output_file, index = False, header=True)
