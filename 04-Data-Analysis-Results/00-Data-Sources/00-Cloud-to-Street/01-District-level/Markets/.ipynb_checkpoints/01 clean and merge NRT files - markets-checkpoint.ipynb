# %%
import pandas as pd
from os import listdir
from os.path import isfile, join
import pathlib
import sys

# insert at 1, 0 is the script path (or '' in REPL)
path_mod = '/Users/srilakshmi/Desktop/Thesis/Data/District-level/'
sys.path.insert(1, path_mod)

import clean

# %%
# file and column names used
col_name_old = "Markets Impacted"

monitor_name_pos_left = 40
monitor_name_pos_right = 57

historic_name_pos_left = 41
historic_name_pos_right = 58

# file paths and file names
path_input = '/Users/srilakshmi/Desktop/Thesis/Data/District-level/Markets/Data-NRT/'

path_output = '/Users/srilakshmi/Desktop/Thesis/Data/District-level/Markets/Output/'
name_output_file = 'District-level_Markets_NRT.csv'

# %%
# # data cleaning functions

# def clean_csv_monitor(string):
    
#     df = pd.read_csv(name_folder_data+string, header=0)
#     df = df.drop_duplicates()
#     df = df.rename(columns={col_name_old: string[monitor_name_pos_left:monitor_name_pos_right]})
#     df = df.sort_values(by=['Region'])
    
#     return df

# def clean_csv_historic(string):
    
#     df = pd.read_csv(name_folder_data+string, header=0)
#     df = df.drop_duplicates()
#     df = df.rename(columns={col_name_old: string[historic_name_pos_left:historic_name_pos_right]})
#     df = df.sort_values(by=['Region'])
    
#     return df

# def special_merge(left,right):
#     merged = left.set_index('Region').join(right.set_index('Region')) # merged file 0 and file 1 together    
#     merged.index.name = 'Region'
#     merged.reset_index(inplace=True)
    
#     return merged

# %%
# get list of file names
files = [f for f in listdir(path_input) if isfile(join(path_input, f))]
files
# Out:
# ['Markets Impacted in Ghana Ghana_Monitor_20200812_20200819.csv',
#  'Markets Impacted in Ghana Ghana_Historic_20190901_20190920.csv',
#  'Markets Impacted in Ghana Ghana_Monitor_20201014_20201021.csv',
#  'Markets Impacted in Ghana Ghana_Monitor_20200805_20200812.csv',
#  'Markets Impacted in Ghana Ghana_Monitor_20200909_20200916.csv',
#  'Markets Impacted in Ghana Ghana_Monitor_20200819_20200826.csv',
#  'Markets Impacted in Ghana Ghana_Monitor_20200826_20200902.csv',
#  'Markets Impacted in Ghana Ghana_Monitor_20200722_20200729.csv',
#  'Markets Impacted in Ghana Ghana_Monitor_20200923_20200930.csv',
#  'Markets Impacted in Ghana Ghana_Monitor_20200916_20200923.csv',
#  'Markets Impacted in Ghana Ghana_Monitor_20200715_20200722.csv',
#  'Markets Impacted in Ghana Ghana_Monitor_20200930_20201007.csv',
#  'Markets Impacted in Ghana Ghana_Historic_20180815_20181015.csv',
#  'Markets Impacted in Ghana Ghana_Monitor_20200902_20200909.csv',
#  'Markets Impacted in Ghana Ghana_Monitor_20201007_20201014.csv']

# %%
# merge csv files

for i in range(0, 1):
    x = clean.clean_csv_monitor(col_name_old, path_input, files[i], monitor_name_pos_left, monitor_name_pos_right)
    y = clean.clean_csv_historic(col_name_old, path_input, files[i+1], historic_name_pos_left, historic_name_pos_right)
    merged = clean.special_merge(left = x, right = y)

for i in range(2, 12):
    z = clean.clean_csv_monitor(col_name_old, path_input, files[i], monitor_name_pos_left, monitor_name_pos_right)
    merged = clean.special_merge(left = merged, right = z)
    
for i in range(12, 13):
    z = clean.clean_csv_historic(col_name_old, path_input, files[i], historic_name_pos_left, historic_name_pos_right)
    merged = clean.special_merge(left = merged, right = z)
    i += 1
    
for i in range(13, 15):
    z = clean.clean_csv_monitor(col_name_old, path_input, files[i], monitor_name_pos_left, monitor_name_pos_right)
    merged = clean.special_merge(left = merged, right = z)
    
merged
# Out:
#                          Region  20200812_20200819  20190901_20190920  \
# 0    Abura / Asebu / Kwamankese                  0                  0
# 1              Accra Metropolis                  0                  0
# 2                      Ada East                  0                  0
# 3                      Ada West                  0                  0
# 4                        Adaklu                  0                  0
# ..                          ...                ...                ...
# 202                  West Gonja                  0                  0
# 203               West Mamprusi                  0                  0
# 204             Yendi Municipal                  0                  0
# 205                  Yilo Krobo                  0                  0
# 206                     Zabzugu                  0                  0
#
#      20201014_20201021  20200805_20200812  20200909_20200916  \
# 0                    0                  0                  0
# 1                    0                  0                  0
# 2                    0                  0                  0
# 3                    0                  0                  0
# 4                    0                  0                  0
# ..                 ...                ...                ...
# 202                  0                  0                  0
# 203                  0                  0                  0
# 204                  0                  0                  0
# 205                  0                  0                  0
# 206                  0                  0                  0
#
#      20200819_20200826  20200826_20200902  20200722_20200729  \
# 0                    0                  0                  0
# 1                    0                  0                  0
# 2                    0                  0                  0
# 3                    0                  0                  0
# 4                    0                  0                  0
# ..                 ...                ...                ...
# 202                  0                  0                  0
# 203                  0                  0                  0
# 204                  0                  0                  0
# 205                  0                  0                  0
# 206                  0                  0                  0
#
#      20200923_20200930  20200916_20200923  20200715_20200722  \
# 0                    0                  0                  0
# 1                    0                  0                  0
# 2                    0                  0                  0
# 3                    0                  0                  0
# 4                    0                  0                  0
# ..                 ...                ...                ...
# 202                  0                  0                  0
# 203                  0                  0                  0
# 204                  0                  0                  0
# 205                  0                  0                  0
# 206                  0                  0                  0
#
#      20200930_20201007  20180815_20181015  20200902_20200909  \
# 0                    0                  0                  0
# 1                    0                  0                  0
# 2                    0                  0                  0
# 3                    0                  0                  0
# 4                    0                  0                  0
# ..                 ...                ...                ...
# 202                  0                  0                  0
# 203                  0                  0                  0
# 204                  0                  0                  0
# 205                  0                  0                  0
# 206                  0                  1                  0
#
#      20201007_20201014
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0
# ..                 ...
# 202                  0
# 203                  0
# 204                  0
# 205                  0
# 206                  0
#
# [207 rows x 16 columns]

# %%
# save file to disk

merged.to_csv(path_output+name_output_file, index = False, header=True)
