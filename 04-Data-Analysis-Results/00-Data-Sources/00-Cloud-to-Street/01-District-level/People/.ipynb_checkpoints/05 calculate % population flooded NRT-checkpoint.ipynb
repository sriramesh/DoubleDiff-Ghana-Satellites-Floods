# %%
import pandas as pd
import geopandas as gpd
from os import listdir
from os.path import isfile, join
import pathlib
import matplotlib.pyplot as plt

# %%
# file paths and names
path_input = '/Users/srilakshmi/Desktop/Thesis/Data/District-level/Totals/'
name_input_file = 'Impacts-Ghana_MaxFlood_20200715_20201014.csv'

path_output = '/Users/srilakshmi/Desktop/Thesis/Treatment-Control-Assignment/Perc-Flooded-NRT/People/'
name_output_file = 'Perc_People_Flooded.csv'

# %%
tot_pop = pd.read_csv(path_input+name_input_file, header=0)

colnames = []
for col in tot_pop.columns:
    colnames.append(col)

tot_pop = tot_pop.dropna(subset=[colnames[2]])
tot_pop = tot_pop[[colnames[1], colnames[2], colnames[6]]]
tot_pop = tot_pop.rename(columns={colnames[1]: "Region", colnames[2]: "Total Pop", colnames[6]: "Flooded Pop"})
tot_pop['Perc Population Flooded'] = list(tot_pop['Flooded Pop']/tot_pop['Total Pop'])

tot_pop = tot_pop.drop(columns=['Total Pop', 'Flooded Pop'])
tot_pop = tot_pop.sort_values(by=['Perc Population Flooded'], ascending=False)

tot_pop
# Out:
#                            Region  Perc Population Flooded
# 2                      Agona West                 0.052515
# 3    Komenda Edna Eguafo / Abirem                 0.035029
# 7                   Gonja Central                 0.025552
# 0                 La Dade Kotopon                 0.020046
# 8                          Karaga                 0.018817
# ..                            ...                      ...
# 199                   Jaman North                 0.000000
# 198                   Jaman South                 0.000000
# 197                   Dormaa West                 0.000000
# 196                       Kadjebi                 0.000000
# 215                      Bia East                 0.000000
#
# [216 rows x 2 columns]

# %%
# save file to disk

tot_pop.to_csv(path_output+name_output_file, index = False, header=True)

# %%
shp_path = '/Users/srilakshmi/Desktop/Thesis/Data/District-level/Districts-Shapefile/gadm36_GHA_2.shp'
ghana_dist = gpd.read_file(shp_path)

var = 'tot_pob'
fig, ax = plt.subplots(figsize=(7, 7))
ghana_dist.plot(ax=ax)

# %%
merged = ghana_dist.set_index('NAME_2').join(tot_pop.set_index('Region'))
merged.index.name = 'NAME_2'
merged.reset_index(inplace=True)

merged = merged.sort_values(by=['Perc Population Flooded'], ascending=False)
merged
# Out:
#                 NAME_2  fid GID_0 NAME_0     GID_1    NAME_1 NL_NAME_1  \
# 81              Karaga   82   GHA  Ghana   GHA.6_1  Northern      None
# 125        Ahanta West  125   GHA  Ghana  GHA.10_1   Western      None
# 120        Krachi East  120   GHA  Ghana   GHA.9_1     Volta      None
# 78          East Gonja   79   GHA  Ghana   GHA.6_1  Northern      None
# 53          Mfantsiman   51   GHA  Ghana   GHA.3_1   Central      None
# ..                 ...  ...   ...    ...       ...       ...       ...
# 131       Sefwi Wiawso  133   GHA  Ghana  GHA.10_1   Western      None
# 133  Shama Ahanta East  134   GHA  Ghana  GHA.10_1   Western      None
# 134   Wasa Amenfi East  135   GHA  Ghana  GHA.10_1   Western      None
# 135   Wasa Amenfi West  136   GHA  Ghana  GHA.10_1   Western      None
# 136         Wassa West  137   GHA  Ghana  GHA.10_1   Western      None
#
#            GID_2                                VARNAME_2 NL_NAME_2  \
# 81     GHA.6.7_1                                     None      None
# 125   GHA.10.1_1                                     None      None
# 120   GHA.9.11_1                                     None      None
# 78     GHA.6.4_1                               East Gonga      None
# 53    GHA.3.12_1                               Mfantseman      None
# ..           ...                                      ...       ...
# 131   GHA.10.9_1                  Sefei Wiaso|Sefwi Wiaso      None
# 133  GHA.10.10_1  Shama Ahanta East Metropolitan Assembly      None
# 134  GHA.10.11_1                                     None      None
# 135  GHA.10.12_1                                Wasa West      None
# 136  GHA.10.13_1                                     None      None
#
#                     TYPE_2              ENGTYPE_2  CC_2    HASC_2  \
# 81                District               District  None      None
# 125               District               District  None  GH.WP.AW
# 120               District               District  None      None
# 78                District               District  None  GH.NP.EG
# 53                District               District  None  GH.CP.MF
# ..                     ...                    ...   ...       ...
# 131               District               District  None  GH.WP.SW
# 133  Metropolitan District  Metropolitan District  None  GH.WP.SA
# 134               District               District  None      None
# 135               District               District  None      None
# 136               District               District  None  GH.WP.WW
#
#                                               geometry  \
# 81   POLYGON ((-0.60242 9.58811, -0.60499 9.59785, ...
# 125  MULTIPOLYGON (((-2.09042 4.74458, -2.09042 4.7...
# 120  POLYGON ((0.21385 7.36813, 0.18954 7.37049, 0....
# 78   POLYGON ((0.08645 8.57350, 0.08549 8.55100, 0....
# 53   POLYGON ((-1.13555 5.39583, -1.12472 5.39706, ...
# ..                                                 ...
# 131  POLYGON ((-2.36110 6.08630, -2.36740 6.07603, ...
# 133  MULTIPOLYGON (((-1.70347 4.94569, -1.70347 4.9...
# 134  POLYGON ((-1.82511 5.57554, -1.82662 5.57551, ...
# 135  POLYGON ((-2.59935 5.44091, -2.59728 5.44642, ...
# 136  POLYGON ((-1.97473 4.91827, -1.98106 4.91394, ...
#
#      Perc Population Flooded
# 81                  0.018817
# 125                 0.015578
# 120                 0.013947
# 78                  0.011641
# 53                  0.010715
# ..                       ...
# 131                      NaN
# 133                      NaN
# 134                      NaN
# 135                      NaN
# 136                      NaN
#
# [137 rows x 16 columns]

# %%
# set a variable that will call whatever column we want to visualise on the map
variable = 'Perc Population Flooded'
colorscale = 'GnBu'

# set the range for the choropleth
vmin, vmax = min(merged[variable]), max(merged[variable])

# create figure and axes for Matplotlib
fig, ax = plt.subplots(1, figsize=(10, 6))

# create map
merged.plot(column=variable, cmap=colorscale, linewidth=0.8, ax=ax, edgecolor='0.8')
# plt.title('Ethiopia '+variable)
plt.title('Ghana Perc Population Flooded, 2020')
plt.xlabel('Longitude')
plt.ylabel('Latitude')

sm = plt.cm.ScalarMappable(cmap=colorscale, norm=plt.Normalize(vmin=vmin, vmax=vmax))
cbar = fig.colorbar(sm)

plt.show()

# %%
name_output_file = 'perc_people_flooded.shp'

merged.to_file(path_output+name_output_file)
